# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Position_Salaries.csv')
X=data.iloc[:,1:-1].values
y=data.iloc[:,-1].values

# %%
from sklearn.linear_model import LinearRegression
model_1=LinearRegression()
model_1.fit(X,y)
y_pred = model_1.predict(X)
print(y_pred)
# Out:
# [-114454.54545455  -33575.75757576   47303.03030303  128181.81818182
#   209060.60606061  289939.39393939  370818.18181818  451696.96969697
#   532575.75757576  613454.54545455]

# %%
plt.scatter(X,y,color="red")
plt.plot(X,model_1.predict(X),color='blue')
plt.title("Simple Linear Regression")
plt.xlabel('Job Rol')
plt.ylabel('Salary')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree=8)
X_new = pf.fit_transform(X)
model_2 = LinearRegression()
model_2.fit(X_new,y)
# Out:
# LinearRegression()

# %%
model_2.predict(X_new)
# Out:
# array([ 45010.38517702,  49906.52128772,  60373.91986602,  79127.52055686,
#        111308.72019386, 148691.27875079, 200872.48128411, 299626.07936279,
#        500093.48189057, 999989.61162939])

# %%
plt.scatter(X,y,color='red')
plt.plot(X,model_2.predict(pf.fit_transform(X)),color='blue')
plt.title("Simple Linear Regression")
plt.xlabel('Job Rol')
plt.ylabel('Salary')
plt.show()

# %%
model_1.predict([[6.5]])
# Out:
# array([330378.78787879])

# %%
model_2.predict(pf.fit_transform([[6.5]]))
# Out:
# array([171303.64880207])
