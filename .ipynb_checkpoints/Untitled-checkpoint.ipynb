# %%
import matplotlib.pyplot as plt
hrs=[1,2,3,4,5,6,7,8]
score=[2,4,5,7,8,9,9,9]
plt.scatter(hrs,score,color='green',marker='*')
plt.title("Student's Data")
plt.ylabel("Score")
plt.xlabel("Hours")
plt.grid(True)
plt.show()
